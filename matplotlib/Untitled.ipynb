# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
xpoints = np.linspace(0,5,10)
#xpoints = np.array([1, 3])

# %%
# ypoints = np.array([8,10])
ypoints = xpoints**2

# %%
plt.plot(xpoints, ypoints, linewidth = '1')
plt.title("Siddhant")
plt.xlabel("Days")
plt.ylabel("Year")
plt.show()

# %%
y = np.array([5,3,7,4])

# %%
#plt.plot(y, marker = 'o',c = 'purple', ls = 'dotted')
plt.plot(y, 'o--r')

# %%
import pandas as pd

# %%
booksales = pd.read_csv('books.csv')

# %%
booksales
# Out:
#                                         Title             Author  \
# 0                    Fundamentals of Wavelets   Goswami, Jaideva
# 1                                  Data Smart      Foreman, John
# 2                    God Created the Integers   Hawking, Stephen
# 3                           Superfreakonomics    Dubner, Stephen
# 4                                 Orientalism       Said, Edward
# 5  Nature of Statistical Learning Theory, The   Vapnik, Vladimir
# 6            Integration of the Indian States         Menon, V P
# 7                        Drunkard's Walk, The  Mlodinow, Leonard
# 8  Image Processing & Mathematical Morphology        Shih, Frank
#
#                Genre  Height         Publisher       Price
# 0  signal_processing     228             Wiley   $4,000.00
# 1       data_science     235             Wiley   $5,000.00
# 2        mathematics     197           Penguin   $7,000.00
# 3          economics     179     HarperCollins  $22,000.00
# ...

# %%
booksales["Height"].plot()
# Out:
# <Axes: >

# %%
booksales['Price'] = booksales['Price'].str.replace('[\$\,]',"")
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_13852\1144500026.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   booksales['Price'] = booksales['Price'].str.replace('[\$\,]',"")

# %%
booksales.dtypes
# Out:
# Title        object
# Author       object
# Genre        object
# Height        int64
# Publisher    object
# Price        object
# dtype: object

# %%
booksales
# Out:
#                                         Title             Author  \
# 0                    Fundamentals of Wavelets   Goswami, Jaideva
# 1                                  Data Smart      Foreman, John
# 2                    God Created the Integers   Hawking, Stephen
# 3                           Superfreakonomics    Dubner, Stephen
# 4                                 Orientalism       Said, Edward
# 5  Nature of Statistical Learning Theory, The   Vapnik, Vladimir
# 6            Integration of the Indian States         Menon, V P
# 7                        Drunkard's Walk, The  Mlodinow, Leonard
# 8  Image Processing & Mathematical Morphology        Shih, Frank
#
#                Genre  Height         Publisher     Price
# 0  signal_processing     228             Wiley   4000.00
# 1       data_science     235             Wiley   5000.00
# 2        mathematics     197           Penguin   7000.00
# 3          economics     179     HarperCollins  22000.00
# ...

# %%
booksales['Price'] = pd.to_numeric(booksales["Price"]).astype(int)     #default float46

# %%
booksales
# Out:
#                                         Title             Author  \
# 0                    Fundamentals of Wavelets   Goswami, Jaideva
# 1                                  Data Smart      Foreman, John
# 2                    God Created the Integers   Hawking, Stephen
# 3                           Superfreakonomics    Dubner, Stephen
# 4                                 Orientalism       Said, Edward
# 5  Nature of Statistical Learning Theory, The   Vapnik, Vladimir
# 6            Integration of the Indian States         Menon, V P
# 7                        Drunkard's Walk, The  Mlodinow, Leonard
# 8  Image Processing & Mathematical Morphology        Shih, Frank
#
#                Genre  Height         Publisher  Price
# 0  signal_processing     228             Wiley   4000
# 1       data_science     235             Wiley   5000
# 2        mathematics     197           Penguin   7000
# 3          economics     179     HarperCollins  22000
# ...

# %%
booksales.dtypes
# Out:
# Title        object
# Author       object
# Genre        object
# Height        int64
# Publisher    object
# Price         int32
# dtype: object
