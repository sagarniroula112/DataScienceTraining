# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
# %matplotlib qt

# %%
data = pd.Series(np.random.randn(1000).cumsum())
data
# Out:
# 0       1.936605
# 1       0.844355
# 2      -0.424200
# 3       0.358719
# 4       1.732118
#          ...
# 995    21.907094
# 996    22.819343
# 997    21.358209
# 998    19.514083
# 999    19.548541
# Length: 1000, dtype: float64

# %%
data.plot()
# Out:
# <Axes: >

# %%
plt.style.use('fivethirtyeight')

# %%
data.plot()
# Out:
# <Axes: >

# %%
df1 = pd.DataFrame(np.random.randn(100, 4), columns = list('ABCD'))

# %%
df1.head()
# Out:
#           A         B         C         D
# 0 -0.104035  1.127635 -0.752661  0.902118
# 1  0.477774  0.366368 -1.278721  1.318549
# 2  1.106367 -1.220501  1.884545  1.267300
# 3  0.672447  0.657443  0.171586 -0.101236
# 4  0.739173 -0.460138  0.458000 -1.175919

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.iloc[10].plot(kind = 'bar') # plot.bar() can also be used
# Out:
# <Axes: >

# %%
df1
# Out:
#            A         B         C         D
# 0  -0.104035  1.127635 -0.752661  0.902118
# 1   0.477774  0.366368 -1.278721  1.318549
# 2   1.106367 -1.220501  1.884545  1.267300
# 3   0.672447  0.657443  0.171586 -0.101236
# 4   0.739173 -0.460138  0.458000 -1.175919
# ..       ...       ...       ...       ...
# 95 -1.410720  0.931691  0.345502 -0.872959
# 96  0.543386 -0.667000 -0.340111  0.467228
# 97  1.804327 -0.995822 -0.693119 -2.385587
# 98 -0.833864 -0.669482 -0.653126  0.138331
# 99  0.680990 -1.064381 -0.420303  0.686704
#
# [100 rows x 4 columns]

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df2 = pd.DataFrame(np.random.randn(7, 3), columns = list('ABC'))

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked = True)
# Out:
# <Axes: >

# %%
df2.plot.barh(stacked = True, orientation = "horizontal")
# Out:
# <Axes: >

# %%
iris = pd.read_csv("iris.data", header = None)
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.columns = ['Sepal_length', 'Sepal_width', 'Petal_length', 'Petal_width', 'class']

# %%
iris
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris['Sepal_length'].corr(iris["Sepal_width"])
# Out:
# -0.10936924995064935

# %%
iris.plot.hist(alpha = 0.5, stacked = True, bins = 25, orientation =  'horizontal')
# Out:
# <Axes: xlabel='Frequency'>

# %%
df1 = iris['Sepal_width'].plot.hist(orientation = 'horizontal')

# %%
iris["Sepal_length"].diff().hist()
# Out:
# <Axes: >

# %%
iris.hist(color = 'red', bins = 20)
# Out:
# array([[<Axes: title={'center': 'Sepal_length'}>,
#         <Axes: title={'center': 'Sepal_width'}>],
#        [<Axes: title={'center': 'Petal_length'}>,
#         <Axes: title={'center': 'Petal_width'}>]], dtype=object)

# %%
iris.hist(by = "class")
# Out:
# array([[<Axes: title={'center': 'Iris-setosa'}>,
#         <Axes: title={'center': 'Iris-versicolor'}>],
#        [<Axes: title={'center': 'Iris-virginica'}>, <Axes: >]],
#       dtype=object)

# %%
# Making box plot

# %%
iris.boxplot()
# Out:
# <Axes: >

# %%
#outliers

# %%
colours = {'boxes': 'red', 'whiskers': 'blue', 'medians':'black', 'caps': 'green'}

# %%
iris.plot.box(color = colours)
# Out:
# <Axes: >

# %%
iris.plot.box(vert = False)
# Out:
# <Axes: >

# %%
plt.rcParams['figure.figsize'] = [8,8]
plt.style.use("ggplot")
iris.boxplot(by = 'class')
# Out:
# array([[<Axes: title={'center': 'Petal_length'}, xlabel='[class]'>,
#         <Axes: title={'center': 'Petal_width'}, xlabel='[class]'>],
#        [<Axes: title={'center': 'Sepal_length'}, xlabel='[class]'>,
#         <Axes: title={'center': 'Sepal_width'}, xlabel='[class]'>]],
#       dtype=object)

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns = list('ABCD'))
df.head()
# Out:
#           A         B         C         D
# 0  0.584651  0.280697  0.739007  0.932557
# 1  0.385961  0.169688  0.723984  0.766107
# 2  0.754231  0.175321  0.116445  0.152222
# 3  0.860047  0.700960  0.779121  0.155343
# 4  0.755193  0.523975  0.454345  0.220304

# %%
df.plot.area(stacked = False)
# Out:
# <Axes: >

# %%
iris = pd.read_csv("imdbratings.txt", header = None)
iris
# Out:
#                0                                                1  \
# 0    star_rating                                            title
# 1            9.3                         The Shawshank Redemption
# 2            9.2                                    The Godfather
# 3            9.1                           The Godfather: Part II
# 4              9                                  The Dark Knight
# ..           ...                                              ...
# 975          7.4                                          Tootsie
# 976          7.4                      Back to the Future Part III
# 977          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Poltergeist
# 979          7.4                                      Wall Street
#
#                   2          3         4  \
# 0    content_rating      genre  duration
# 1                 R      Crime       142
# 2                 R      Crime       175
# ...

# %%
df.plot.scatter(x= "A", y ="B")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
movies = pd.read_csv('imdbratings.txt',)

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
